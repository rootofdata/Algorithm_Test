# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 4 6
# 19 15 10 17

n,m = 4,6
array = [19,15,10,17]
result = 0
start = 0
end = max(array)
while end>=start:
    total =0
    for i in array:
        if i-end >0:
            total += (i-end)
    if total == m:
        result = end
        break
    else :
        end-=1
result
# Out:
# 15
