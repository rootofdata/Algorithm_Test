# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=30
a = [i for i in range(1,n+1)]
for i in range(28):
    b = int(input())
    a.pop(a.index(b))
print(a[0])
print(a[1])
# Out:
# 2
# 8
