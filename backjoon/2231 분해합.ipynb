# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
result = 0
for i in range(N+1):
    num=list(map(int,str(i)))
    result = sum(num)+i
    if result == N:    
        print(i)
        break
    elif i == N:
        print(0)
# Out:
# 198
