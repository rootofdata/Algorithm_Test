# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
M = list(map(int,input().split()))

M = sorted(M)
tot = [0]*N
tot[0]=M[0]
for i in range(1,N):
    tot[i] = M[i]+tot[i-1]
    
print(sum(tot))
# Out:
# 32
