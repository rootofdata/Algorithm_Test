# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
a=[]
for i in range(N):
    a.append(int(input()))
a=sorted(a,reverse=False)
for j in range(N):
    print(a[j])
# Out:
# 1
# 2
# 3
# 4
# 5
