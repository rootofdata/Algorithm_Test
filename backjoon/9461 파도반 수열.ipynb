# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = int(input())
# 1,4 =5 2,5=7 [2,6] ->[7]  [3,7]->[8]

a=[0]*100
a[0]=1
a[1]=1
a[2]=1
a[3]=2
a[4]=2

for i in range(T):
    N=int(input())
    for i in range(5,N):
        a[i]=a[i-5]+a[i-1]
    print(a[N-1])


#a[5]=a[0]+a[4]=3
#a[6]=a[1]+a[5]=4
#a[7]=5=a[2]+a[6]
# Out:
# 3
# 16
