# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N,K = map(int,input().split())
A = list(map(int,input().split()))

def merge_sort(A,p,r):
    if p<r:
        q=(p+r)//2
        merge_sort(A,p,q)
        merge_sort(A,q+1,r)
        merge(A,p,q,r)
    if ans !=-1:
        return
    
def merge(A,p,q,r):
    global cnt,ans
    tmp = [0]*(r-p+2)
    i=p
    j=q+1
    t=1
    while i <= q and j <= r :
        if A[i] <= A[j]: 
            tmp[t] = A[i] 
            t+=1; i+=1
        else: 
            tmp[t] = A[j]
            t+=1; j+=1
    
    while i <= q:
        tmp[t] = A[i]
        t+=1;i+=1
    while j <= r: 
        tmp[t] = A[j]
        t+= 1; j+=1
    i = p; t = 1
    while (i <= r):
        A[i] = tmp[t]; 
        i += 1; t += 1; cnt += 1
        if cnt == K:
            ans = A[i-1]
            return
cnt = 0
ans = -1

merge_sort(A,0,N-1)
print(ans)
# Out:
# 3
