# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N,K = map(int,input().split())
ans = []
for i in range(1,N+1):
    if N%i==0:
       ans.append(i)
if len(ans)>=K:
    print(ans[K-1])
else :
    print(0)
# Out:
# 0
