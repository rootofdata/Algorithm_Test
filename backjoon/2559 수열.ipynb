# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N,K = map(int,input().split())
a=[]
M = list(map(int,input().split()))

Max = sum(M[0:K])
Temp = Max

for i in range(N-K):
    Temp = Temp - M[i]+M[i+K]
    if Max < Temp:
        Max = Temp
        
print(Max)
# Out:
# 21
