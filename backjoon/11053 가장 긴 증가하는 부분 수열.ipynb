# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
A = list(map(int,input().split()))

# %%
N = int(input())
A = list(map(int,input().split()))
count = [0]*N

for i in range(N):
    for j in range(i):
        if A[j]<A[i] and count[i]<count[j]:
            count[i] = count[j]
    count[i] +=1
print(count[N])
# Out:
# [1, 2, 1, 3, 2, 4]
