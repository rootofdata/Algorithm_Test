# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = int(input())
for _ in range(T):
    a = list(str(input()))
    ans=0
    for i in a:
        if i == '(':
            ans+=1
        else:
            ans-=1
        if ans <0:
            break
    if ans==0:
        print('YES')
    else:
        print('NO')
# Out:
# NO
# NO
# NO
# YES
# NO
# YES
# NO
