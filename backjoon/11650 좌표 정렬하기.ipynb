# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
x=[]
for i in range(N):
    x.append(list(map(int,input().split())))
a = sorted(x,reverse=False)
for i in a:
    print(*i)
# Out:
# 1 -1
# 1 1
# 2 2
# 3 3
# 3 4
