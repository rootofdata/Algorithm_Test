# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b = map(int,input().split())

s1 = set(map(int,input().split()))
s2 = set(map(int,input().split()))

s = set(s1&s2)
print(len(s1-s) + len(s2-s))
# Out:
# 4
