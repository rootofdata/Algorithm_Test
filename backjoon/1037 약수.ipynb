# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
a = list(map(int,input().split()))

ans = max(a)*min(a)
print(ans)
# Out:
# 185192

# %%
N = int(input())
a = list(map(int,input().split()))

ans = max(a)*min(a)
print(ans)
# Out:
# 24
