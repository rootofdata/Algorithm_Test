# %% [markdown]
# ![image.png](attachment:image.png)

# %%
S = input()
q = int(input())


for _ in range(q):
    check,start,end = map(str,input().split())
    start = int(start)
    end = int(end)
    cnt = 0
    for i in S[start:end+1]:
        if i ==check:
            cnt+=1
    print(cnt)
# Out:
# 0
# 1
# 2
# 1
