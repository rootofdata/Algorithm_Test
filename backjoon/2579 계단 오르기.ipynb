# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 오답 로직

N = int(input())
tot = 0
a=[]
b=[0]*N
for i in range(N):
    a.append(int(input()))
def af(ka,N):
    for i in range(ka,N-2):
        c1=a[i]
        c2=a[i]
        if max(a[i],a[i+1]) == a[i]:
            b[i] = a[i]
        else:
            b[i] = a[i+1]
            af(i+2,N)
            return
    if N >=4:
        if max(a[-4],a[-3])==a[-4]:
            b[N] = a[-2] +a[-1]
        else:
            b[N] = a[-1]
    else:
        b[N]=a[-1]
af(0,N-1)

print(sum(b))
# Out:
# 10

# %%
N = int(input())
Stairs = [0] * (N+3)
MaxList = [0] * (N+3)

# [0]: 마지막 한 칸에 대한 덧셈
# [1]: 연속된 두 칸에 대한 덧셈

Con = [0] * 2
for i in range(3,N+3):
    Stairs[i] = int(input())
    Con[0] = MaxList[i-2] + Stairs[i]
    Con[1] = MaxList[i-3] + Stairs[i-1] + Stairs[i]
    MaxList[i] = max(*Con)
#    print(Con)

# print("Stairs: ", Stairs)
# print("MaxList: ", MaxList)
print(MaxList[N+2])
# Out:
# [1, 1]
# [3, 4]
# [6, 8]
# [11, 13]
# [17, 20]
# [13, 17]
# Stairs:  [0, 0, 0, 1, 3, 5, 7, 9, 0]
# MaxList:  [0, 0, 0, 1, 4, 8, 13, 20, 17]
# 17
