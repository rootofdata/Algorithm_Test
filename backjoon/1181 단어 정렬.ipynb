# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#import sys
# input = sys.stdin.readline

N = int(input())
a=[]
for i in range(N):
   a.append(str(input()))
a = list(set(a))
a.sort()
a.sort(key=len)
for i in a:
    print(i)
# Out:
# ['but',
#  'i',
#  'wont',
#  'hesitate',
#  'no',
#  'more',
#  'no',
#  'more',
#  'it',
#  'cannot',
#  'wait',
#  'im',
#  'yours']
