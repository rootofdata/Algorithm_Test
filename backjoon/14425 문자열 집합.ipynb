# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 오답
N,M = map(int,input().split())
n_list =[]
m_list =[]
for i in range(N):
    n_list.append(input())
for j in range(M):
    m_list.append(input())
    
n1=set(n_list)
m1=set(m_list)
print(len(n1&m1))
# Out:
# 4

# %%
# 정답
N,M = map(int,input().split())
n_list =[]
m_list =[]
for i in range(N):
    n_list.append(input())
for j in range(M):
    m_list.append(input())
n1=set(n_list)
tot = 0
for i in m_list:
    if i in n1:
        tot +=1
print(tot)
# Out:
# 4
