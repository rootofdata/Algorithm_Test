# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
m = list(map(int,input().split()))
answer =0
for i in m:
    ans =[]
    for j in range(1,i+1):
        if i%j==0:
            ans.append(j)
    if len(ans)==2:
        answer +=1
print(answer)
