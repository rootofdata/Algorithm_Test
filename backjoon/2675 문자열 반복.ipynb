# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = int(input())

for i in range(T):
    a=''
    R,S = input().split()
    R = int(R)
    S = str(S)
    for i in range(len(S)):
        a+=S[i]*R
    print(a)
# Out:
# aaabbbccc
# hhhhhtttttppppp
