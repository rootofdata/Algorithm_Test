# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n= int(input())
x_zip=[]
y_zip=[]
for _ in range(n):
    x,y = map(int,input().split())
    x_zip.append(x)
    y_zip.append(y)

x_zip = sorted(x_zip)
y_zip = sorted(y_zip)
if n ==1:
    print(0)
else:
    print((x_zip[-1]-x_zip[0])*(y_zip[-1]-y_zip[0]))
# Out:
# 360
