# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N,M = map(int,input().split())
l1=[]

def rec(m):
    if len(l1)<M:
        for i in range(m,N+1):
            l1.append(i)
#            print('-',l1)
            rec(i)
            l1.pop()
    else:
        print(*l1)
rec(1)
# Out:
# 1 1
# 1 2
# 1 3
# 1 4
# 2 2
# 2 3
# 2 4
# 3 3
# 3 4
# 4 4
