# %% [markdown]
# ![](attachment:image.png)image.png

# %%
from itertools import permutations as per

N,M = map(int,input().split())
number = [i for i in range(1,N+1)]
perm = list(per(number,M))
# Out:
# [(1,), (2,), (3,), (4,)]

# %%
N,M = map(int,input().split())
l1=[]

def rec():
    if len(l1)<M:
        for i in range(1,N+1):
            l1.append(i)
            rec()
            l1.pop()
    else:
        print(*l1)
rec()
# Out:
# [1, 1]
# [1, 2]
# [1, 3]
# [2, 1]
# [2, 2]
# [2, 3]
# [3, 1]
# [3, 2]
# [3, 3]
