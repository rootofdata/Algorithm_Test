# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import heapq
n = int(input())
heap = []

for i in range(n):
    x=int(input())
    if not x:
        if heap:
            print(heapq.heappop(heap))
        else:
            print(0)
    else:
        heapq.heappush(heap,x)
# Out:
# 0
# 1
# 2
# 12345
# 0

# %%
import heapq
N = int(input())
heap = []
for i in range(N):
    x = int(input())
    if not x:
        if heap:
            print(-heapq.heappop(heap))
        else:
            print(0)
    else:
        heapq.heappush(heap,-x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-89c50c0ef10d> in <module>
#       1 import heapq
# ----> 2 N = int(input())
#       3 heap = []
#       4 for i in range(N):
#       5     x = int(input())
#
# ValueError: invalid literal for int() with base 10: ''
