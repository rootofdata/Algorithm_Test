# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
M = input()
b= set()
cnt = 0
for i in range(N-1):
    a = input()
    b.add(a)
    if a == 'ENTER':
        cnt+= len(b)-1
        b = set()
cnt+=len(b)
print(cnt)
print(b)
# Out:
# 5
# {'pjs', 'chan'}

# %%
N = int(input())
M = input()
b= set()
cnt = 0
for i in range(N-1):
    a = input()
    if a == 'ENTER':
        cnt+= len(b)
        b = set()
    b.add(a)
cnt+=len(b)
cnt
# Out:
# 8
