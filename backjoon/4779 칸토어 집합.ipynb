# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def cantor(a, b):
    if b==1: return
    for i in range(a + b//3,a + b//3*2):
        res[i] = ' '
    cantor(a,b//3)
    cantor(a+b//3*2,b//3)
    
while 1:
    try:
        n = int(input().rstrip())
        res = ['-']*(3**n)
        cantor(0,3**n)
        print(''.join(res))
    except Exception as e:
#        print(e)
        break
# Out:
# - -
# - -   - -         - -   - -
# - -   - -         - -   - -                           - -   - -         - -   - -                                                                                 - -   - -         - -   - -                           - -   - -         - -   - -
# - -

# %%
def cantor(s):
    l=len(s)//3
    if l==0:
        return '-'
    return cantor('-'*l)+' '+cantor('-'*l)
while True:
    try:
        n=int(input())
        print(cantor('-'*(3**n)))
    except:
        break
# Out:
# - -
