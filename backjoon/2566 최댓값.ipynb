# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a_list = []
max_ = 0
max_i = 0
max_j = 0
for i in range(9):
    a_list.append(list(map(int,input().split())))
for j in range(9):
    for k in range(9):
        if max_ <a_list[j][k]:
            max_=max(max_,a_list[j][k])
            max_i= j
            max_j = k 
print(max_)
print(max_i+1,max_j+1)
# Out:
# 87
# 9 1
