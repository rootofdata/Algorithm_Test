# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def fibonachi(n):  
    if n==0:
        ans=0
    if n==1:
        ans=1
    if n>=2:
        for i in range(2,n+1):
            ans= fibonachi(i-1)+fibonachi(i-2)
    return ans

n = int(input())
print(fibonachi(n))
# Out:
# 1597
