# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 완전 오답
N = str(input())
a=[]
tot=0
N = list(N)

for i in range(len(N)):
    if N[i] != '+' and N[i] != '-':
        a.append(int(N[i]))
    if N[i] =='+':
        tot = sum(a)
        a=[]
    elif i == '-':1541 vkdl
        tot -= sum(a)
        a=[]        
    tot += sum(a)
tot
# Out:
# 23

# %%
# split 통한 해결... 
N = input()
N_new = N.split('-')

result = sum(map(int,N_new[0].split('+')))
for i in N_new[1:]:
    result -= sum(map(int,i.split('+')))
    
print(result)
# Out:
# -35
