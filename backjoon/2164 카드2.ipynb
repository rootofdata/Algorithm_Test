# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from collections import deque
N = int(input())
a = deque()
for i in range(1,N+1):
    a.append(i)
while len(a)>1:
    a.popleft()
    a.append(a[0])
    a.popleft()
print(a[0])
# Out:
# 4
