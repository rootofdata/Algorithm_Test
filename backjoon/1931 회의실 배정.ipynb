# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
ans = []
for _ in range(N):
    ans.append(list(map(int,input().split())))
ans.sort(key=lambda x:(x[1],x[0]))

count = 0
end = 0
for i in range(N):
    next_start,next_end = ans[i]
    if end<=next_start:
        count +=1
        end = next_end
print(count)
# Out:
# 4
