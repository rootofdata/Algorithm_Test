# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())

wine = [0]*(N+3)
maxi = [0]*(N+3)

con = [0]*2
for i in range(N):
    wine[i] = int(input())
    con[0] = maxi[i-2] + wine[i]
    con[1] = maxi[i-3] + wine[i-1] + wine[i]
    maxi[i] = max(*con,maxi[i-1])
print(max(maxi))
# Out:
# 33

# %%
print(maxi)
# Out:
# [6, 6, 6, 6, 6, 6, 0, 0, 0]
