# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 오류
N = int(input())
cnt = 0
aset = set()
for i in range(N):
    A,B = map(str,input().split())
    if B=='ChongChong':
        aset=set()
    aset.add(A)
    aset.add(B)
print(len(aset))
# Out:
# 10

# %%
import sys
input = sys.stdin.readline
N = int(input())

aset = set(['ChongChong'])
for _ in range(N):
    A,B = input().split()
    if A in aset or B in aset:
        aset.add(a)
        aset.add(b)
    
print(len(aset))

# %%
import sys
input = sys.stdin.readline
N = int(input())
aset = set(["ChongChong"])
for _ in range(N):
    a,b = input().split()
    if a in aset or b in aset:
        aset.add(a)
        aset.add(b)
print(len(aset))
