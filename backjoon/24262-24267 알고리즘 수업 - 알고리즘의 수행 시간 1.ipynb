# %% [markdown]
# ### 알고리즘 수업 - 알고리즘의 수행 시간 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n= 100
def Menofpassion(n):
    i = n//2
    print(i)
    cal = 0
    cal +=1
    if i <=1:
        return cal
    else:
        return Menofpassion(i)
Menofpassion(100)
# Out:
# 50
# 25
# 12
# 6
# 3
# 1
# 1

# %%
# 다 무시하고 시간복잡도 구하라는 문제...

print(1)
print(0)

# %% [markdown]
# ### 알고리즘 수업 - 알고리즘의 수행 시간 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
print(n)
print(0)
# Out:
# 0

# %% [markdown]
# ### 알고리즘 수업 - 알고리즘의 수행 시간 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
print(n*n)
print(2)

# %% [markdown]
# ### 알고리즘 수업 - 알고리즘의 수행 시간 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
print(int((n*(n-1))/2))
print(2)

## 1-6 : 6

## n *1 + (n-1)*2 + ... + 1  -> n*(n-1)/2
# Out:
# 21
# 2

# %% [markdown]
# ### 알고리즘 수업 - 알고리즘의 수행 시간 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n= int(input())
print(n*n*n)
print(3)

# n*n*n

# %% [markdown]
# ### 알고리즘 수업 - 알고리즘의 수행 시간 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# (n-2)*(n-i)*n -> n^3 -n*n*(n+1)

n= int(input())

cnt = 0
for i in range(1,n-1):
    cnt+= (n-i-1)*(n-i)//2
#    for j in range(i+1,n):
#        for k in range(j+1,n+1):
#            cnt+=1

print(cnt)
print(3)
