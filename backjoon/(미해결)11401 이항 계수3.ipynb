# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 미해결

# %%
A,B = map(int,input().split())
ans = 1
last = 1000000007
def fac(N):
    ans=1
    for i in range(2,N+1):
        i = i%last
        ans=ans*i
    return ans

def power(num,p,mod):
    if p ==1:
        return num&mod
    if p%2:
        return power(num,p//2,mod)


int((fac(A)/(fac(B)*fac(A-B))))
# Out:
# 10

# %%
A,B,C = map(int,input().split())
ans = 1

def power(A,B):
    if B==1:
        return A%C
    else:
        tmp =power(A,B//2)
        if B%2==0:
            return tmp*tmp%C
        else:
            return tmp*tmp*A%C
print(power(A,B))
