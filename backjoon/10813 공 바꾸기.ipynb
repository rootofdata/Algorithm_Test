# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,m = map(int,input().split())
a_list = [i for i in range(1,n+1)] #0 1 2 3 4

for _ in range(m):
    i,j = map(int,input().split())
    a_list[i-1],a_list[j-1] = a_list[j-1],a_list[i-1]
print(*a_list)
# Out:
# [3, 1, 4, 2, 5]
