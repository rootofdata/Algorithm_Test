# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
x=[]
for i in range(N):
    a,b = map(str,input().split())
    a = int(a)
    x.append([a,b])
x.sort(key =lambda x:(x[0]))

for i in x:
    print(*i)
# Out:
# 20 Sunyoung
# 21 Junkyu
# 21 Dohyun
