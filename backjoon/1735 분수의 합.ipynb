# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b = map(int,input().split())
c,d = map(int,input().split())

bunja = (a*d+b*c)
a = bunja
bunmo = b*d
b= bunmo
while True:
    bunja,bunmo = bunmo,bunja % bunmo
    if bunmo<=0 or bunja<=0:
        break
print(a//bunja,b//bunja)
# print(bunja//gcd,bunmo//gcd)
# Out:
# 31 35
