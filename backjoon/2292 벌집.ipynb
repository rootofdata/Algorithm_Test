# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1
# 2-7 : 2
# 8-19 : 3
# 20-37 : 4
# 38-61 : 5

#6 12 18 24
answer = 1
n= int(input())
for i in range(n//2):
    answer+=(6*i)
    if n <= answer:
        a = i+1
        break
if n==1:
    a=0
print(a)

## 런타임 에러 => for문의 범위가 애매함. 그래서 While 문으로 적용
# Out:
# 0

# %%
answer = 1
d = 1
n= int(input())
while True:
    if n<=answer:
        break
    answer +=6*d
    d+=1       

print(d)
# Out:
# 1
