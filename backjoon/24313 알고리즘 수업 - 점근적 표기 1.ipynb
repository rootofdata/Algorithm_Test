# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a1,a2=map(int,input().split())
c = int(input())
n0 = int(input())
n=n0
if ((a1*n0+a2<=c*n0)) and (a1<=c):
    print(1)
else:
    print(0)
# Out:
# 1
