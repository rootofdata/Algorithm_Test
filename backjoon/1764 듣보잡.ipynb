# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N,M = map(int,input().split())
s1 = set()
s2 = set()
for i in range(N):
    a = input()
    s1.add(a)
for j in range(M):
    a = input()
    s2.add(a)
s = set(s1&s2)
s = sorted(s)
print(len(s))
for i in s:
    print(i)
# Out:
# 2
# baesangwook
# ohhenrie
