# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A,B,C = map(int,input().split())

print(A**B%C)
# Out:
# 4

# %%
A,B,C = map(int,input().split())
ans = 1

def power(A,B):
    if B==1:
        return A%C
    else:
        tmp =power(A,B//2)
        if B%2==0:
            return tmp*tmp%C
        else:
            return tmp*tmp*A%C
print(power(A,B))
# Out:
# 4
