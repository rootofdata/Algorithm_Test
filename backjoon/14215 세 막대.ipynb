# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b,c =map(int,input().split())
max_value = max(a,b,c)
if max_value >= a+b+c-max_value:
    max_value = a+b+c-max_value-1
print(max_value+a+b+c-max(a,b,c))
# Out:
# 3
