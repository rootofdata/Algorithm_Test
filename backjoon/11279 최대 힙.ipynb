# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import heapq
N = int(input())
heap = []
for i in range(N):
    x = int(input())
    if not x:
        if heap:
            print(-heapq.heappop(heap))
        else:
            print(0)
    else:
        heapq.heappush(heap,-x)
# Out:
# 0
# 2
# 1
# 3
# 2
# 1
# 0
# 0
