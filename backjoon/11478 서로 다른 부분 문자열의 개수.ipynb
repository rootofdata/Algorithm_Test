# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 5 
# 1 -> 5
# 2 -> 4
# 3 -> 3
# 4 -> 2
# 5 -> 1

# %%
S = input()
a=set()
for i in range(len(S)):
    for j in range(i,len(S)+1):
        a.add(S[i:j])
print(len(a)-1)
# Out:
# 12
