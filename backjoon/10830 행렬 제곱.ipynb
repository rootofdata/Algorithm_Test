# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N,B = map(int,input().split())
a_list =[]
b_list =[]
for i in range(N):
    a_list = list(map(int,input().split()))
    b_list.append(a_list)

B=2
a = [[0]*N for _ in range(N)]
c_list = b_list
for _ in range(B):
    for i in range(N):
        for j in range(N):
            for l in range(N):
                a[i][j] += c_list[i][j] *b_list[j][i]
            c_list[i][j] = a[i][j]
a
# Out:
# [[30, 20760, 250110],
#  [17936928, 16950, 1493136],
#  [992687913, 15480837504, 177390]]

# %%
b_list
# Out:
# []

# %%
B=2
a_list =[]
b_list =[]
a = [[0]*N for _ in range(N)]
c_list = b_list
for _ in range(B):
    for i in range(N):
        for j in range(N):
            for l in range(N):
                a[i][j] += c_list[i][j] *b_list[j][i]
            c_list[i][j] = a[i][j]
a
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-9dc5448a2b6f> in <module>
#       8         for j in range(N):
#       9             for l in range(N):
# ---> 10                 a[i][j] += c_list[i][j] *b_list[j][i]
#      11             c_list[i][j] = a[i][j]
#      12             print(c_list)
#
# IndexError: list index out of range

# %%
c_list
# Out:
# [[2, 210060], [408358584, 65792]]

# %%
# 1 2  1 2   -> 1+3, 2+8
# 3 4  3 4   -> 3+12 6+16

# %%
for i in range(N):
    for j in range(K):
        for l in range(M):
            ans[i][j] += (N_list[i][l]*M_list[l][j])
    
for i in range(N):
    print(*ans[i])
