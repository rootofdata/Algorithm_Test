# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from collections import deque
N,K = map(int,input().split())

a = deque(range(1,N+1))

print(end='<')
while len(a)>1:
    a.rotate(-K)
    print(a.pop(),end=', ')
print(a.pop(),end='>')
# Out:
# <3, 6, 2, 7, 5, 1, 4>
