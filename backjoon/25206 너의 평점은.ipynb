# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
count = 0
total = 0
table = {'A+':4.5, 'A0':4.0, 'B+':3.5, 'B0':3.0, 'C+':2.5, 'C0':2.0, 'D+':1.5, 'D0':1.0, 'F':0.0, 'P':0.0}
for i in range(20):
    N,M,K = input().split()
    if K !='P':
        count+=table[K] *float(M)
        total+=float(M)
print(round(count/total,6))
# Out:
# 4.25
