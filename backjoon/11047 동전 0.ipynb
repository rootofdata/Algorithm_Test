# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N,K = map(int,input().split())
coin_list = []
for i in range(N):
    coin_list.append(int(input()))
    
cnt = 0
for i in range(len(coin_list)-1,-1,-1):
    if coin_list[i]<=K:
        cnt = cnt+K//coin_list[i]
        K %= coin_list[i]

print(cnt)
# Out:
# 6
