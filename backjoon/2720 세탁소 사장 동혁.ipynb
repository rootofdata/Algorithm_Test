# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
for i in range(n):
    a = int(input())
    q = a//25
    d = (a-q*25)//10
    n = (a-q*25-d*10)//5
    p = (a-q*25-d*10-n*5)
    print(q,d,n,p)
# Out:
# 4 2 0 4
