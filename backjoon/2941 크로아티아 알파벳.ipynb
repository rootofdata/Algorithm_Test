# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=['c=','c-','dz=','d-','lj','nj','s=','z=']

b= input()
answer =0
for i in a:
    if i in b:
        b=b.replace(i,'?')
answer += len(b)

print(answer)
# Out:
# lj
# nj
# s=
# 6
