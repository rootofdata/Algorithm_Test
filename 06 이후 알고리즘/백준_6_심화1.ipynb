# %% [markdown]
# 25083 새싹
# ![image.png](attachment:image.png)

# %%
print("         ,r'\"7")
print("r`-_   ,'  ,/")
print(" \\. \". L_r'")
print("   `~\\/")
print("      |")
print("      |")
# Out:
#          ,r'"7
# r`-_   ,'  ,/
#  \. ". L_r'
#    `~\/
#       |
#       |

# %% [markdown]
# 3003 킹, 퀸, 룩, 비숍, 나이트, 폰
# ![image.png](attachment:image.png)

# %%
a = [1,1,2,2,2,8]
a_list = list(map(int,input().split()))
for i in range(6):
    a_list[i]=a[i]-a_list[i]
print(*a_list)
# Out:
# [0, 1, 2, 2, 2, 7]

# %% [markdown]
# 2444 별 찍기 -7
# ![image.png](attachment:image.png)

# %%
N = int(input())
for i in range(1,N):
      print(' '*(N-i) + '*'*(2*i-1))
for i in range(N, 0, -1):
  print(' '*(N-i)+'*'*(2*i-1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %% [markdown]
# 10988 팰린드롬인지 확인하기
# ![image.png](attachment:image.png)

# %%
N = list(input())
A = N[::-1]
if A==N:
    print(1)
else:
    print(0)

# %%
if A==N:
    print(1)
else:
    print(0)
# Out:
# 1

# %% [markdown]
# 1157 단어 공부
# ![image.png](attachment:image.png)

# %%
N = input()
N = N.upper()
N_list = list(set(N))
cnt_list = []
for i in N_list:
    cnt = N.count(i)
    cnt_list.append(cnt)
if cnt_list.count(max(cnt_list))>1:
    print('?')
else:
    print(N_list[cnt_list.index(max(cnt_list))])
# Out:
# Z

# %% [markdown]
# 2941 크로아티아 알파벳
# ![image.png](attachment:image.png)

# %%
N = input()

dic = ['c=','c-','dz=','d-','lj','nj','s=','z=']

for i in dic:
    N = N.replace(i,'*')
print(len(N))
# Out:
# 6

# %% [markdown]
# 1315 그룹 단어 체커
# ![image.png](attachment:image.png)

# %%
N = int(input())
for i in range(N):
    word = input()
a = sorted(word,key=word.find)
if a==word:
    cnt+=1

# %%
n = int(input())
cnt = n
for i in range(n):
    a = input()
    for j in range(len(a)-1):
        if a[j] == a[j+1]:
            pass
        elif a[j] in a[j+1:]:
            cnt -= 1
            break
print(cnt)

# %% [markdown]
# 25206 너의 평점은
# ![image.png](attachment:image.png)

# %%
score_dic = {'A+':4.5,'A0':4, 'B+':3.5,'B0':3,'C+':2.5,'C0':2,'D+':1.5,'D0':1,'F':0,'P':0}
result = 0
ans=0
for _ in range(20):
    sub,tot,score = input().split()
    if score !='P':
        ans +=float(tot)
        result +=score_dic[score]*float(tot)
print(round(result/ans,6))
# Out:
# 80.0
