# %% [markdown]
# ### 10869 사칙연산

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A,B = map(int,input().split())
print(A+B)
print(A-B)
print(A*B)
print(A//B)
print(A%B)
# Out:
# 10
# 4
# 21
# 2
# 1

# %% [markdown]
# ### 10926 ??!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = input()

print(A+'??!')
# Out:
# joonas??!

# %% [markdown]
# ### 18108 1998년생인 내가 태국에서는 2541년생?!

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
a = int(input())
print(a-543)
# Out:
# 1998

# %% [markdown]
# ### 10430 나머지

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A,B,C = map(int,input().split())

print((A+B)%C)
print(((A%C)+(B%C))%C)
print((A*B)%C)
print(((A%C)*(B%C))%C)
# Out:
# 1
# 1
# 0
# 0

# %% [markdown]
# ### 2588 곱셈

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input())
b = int(input())

print(a*(b%10))
print(a*(b-(b//100)*100-b%10)//10)
print(a*(b//100))
print(a*b)
# Out:
# 2360
# 3776
# 1416
# 181720

# %%
a= int(input())
b= int(input())

list_b = list(str(b))
int_b = [int(b) for b in list_b]

print(a*int_b[2])
print(a*int_b[1])
print(a*int_b[0])
print(a*b)
# Out:
# 2360
# 3776
# 1416
# 181720

# %% [markdown]
# 11382 꼬마 정민

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b,c=map(int,input().split())

print(a+b+c)
# Out:
# 7931

# %% [markdown]
# 10171 고양이

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("|\\_/|")
print("|q p|   /}")
print('( 0 )"""\\')
print('|"^"`    |')
print("||_/=\\\__|")
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|
